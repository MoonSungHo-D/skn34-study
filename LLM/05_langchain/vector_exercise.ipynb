# %%
# Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

vector_a = np.array([[1, 0, -1]])
vector_b = np.array([[0, 1, -1]])

similarity = cosine_similarity(vector_a, vector_b)
similarity[0][0]
# Out:
# np.float64(0.4999999999999999)

# %%
# Faiss (L2 거리 기반 인덱싱 기법 적용)
import faiss
import numpy as np

dimension = 128
data = np.random.random((100, dimension)).astype('float32')
query = np.random.random((1, dimension)).astype('float32')

index = faiss.IndexFlatL2(dimension)
index.add(data)

k = 5
distances, indices = index.search(query, k)
print(f"검색 결과 인덱스 : {indices}")
print(f"유사도 거리 : {distances}")
# Out:
# 검색 결과 인덱스 : [[33 54  5  7 49]]
# 유사도 거리 : [[16.696325 17.527815 17.892624 18.13758  18.350248]]
