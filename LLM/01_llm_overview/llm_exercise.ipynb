# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_KEY = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=OPENAI_KEY)

response = client.responses.create(
    model="gpt-5-nano",
    input="AI 최근 동향에 대해 심도깊은 고찰을 하는중이다. 뭐가 요즘 핫한가?",
)

print(response.output_text)
# Out:
# 요즘 AI 트렌드를 한눈에 보면 대체로 다음과 같은 흐름들이 핫하게 떠오르고 있습니다. 특정 분야나 지역에 따라 포커스가 다를 수 있지만, 전반적으로 공통적으로 주목받는 이슈들입니다.
#
# 1) 대형 모델의 진화와 에이전트 기반 시스템
# - 대형 언어 모델(LM)과 멀티모달 모델이 더 강력해지고, 이를 바탕으로 도구를 조합해 자체적으로 문제를 해결하는 에이전트(agent) 시도가 활발합니다.
# - 코드 작성, 데이터 분석, 자동화된 의사결정, 대화형 에이전트의 복합 작업 수행 등 응용 범위가 넓어지고 있습니다.
# - 모델 간의 협업, 멀티모달 입력(텍스트+이미지+음성+비디오) 처리 및 멀티태스크 능력이 핵심 포인트로 자리 잡고 있습니다.
#
# 2) 멀티모달 및 멀티에이전트 생태계 확장
# - 텍스트-이미지-오디오-비디오를 함께 다루는 멀티모달 모델과, 서로 다른 모델이 협력하는 멀티에이전트 시스템이 많아지고 있습니다.
# - RAG(검색 기반 생성)나 지식증강(지식베이스 활용) 접근법이 여전히 중요하고, 실시간 지식 업데이트와 안전성 문제가 활발히 연구됩니다.
#
# 3) 안전성, 거버넌스, 규제의 중요성 증가
# - 악용 방지, 편향 감소, 설명가능성, 모델 카드·데이터 카드 등 투명성 요구가 커졌습니다.
# - 각국의 규제 도입/정비와 함께 기업의 책임 있는 AI 도입 요구가 확대되고 있습니다.
# - 안전 평가, 레드팀 테스트, 학습 데이터의 품질 관리가 상용화된 도구와 프로세스로 정착 중입니다.
#
# 4) 데이터 중심 AI와 데이터 관리의 재조명
# - 데이터 품질이 성능의 결정 요인으로 여겨지며, 데이터 거버넌스, 데이터 수집/주석의 표준화, 데이터 합성 데이터의 신뢰성 연구가 활발합니다.
# - 개인 정보 보호와 프라이버시 강화도 중요 이슈로 남아 있습니다(연합학습, 차등 프라이버시, 합성 데이터 활용 등).
#
# 5) 효율성/하드웨어 중심의 기술 트렌드
# - 파라미터 효율적 튜닝(예: LoRA/Adapter), 양자화, 스파싱 등으로 비용과 에너지 소비를 낮추려는 노력이 계속됩니다.
# - 온디바이스 AI, 엣지 컴퓨팅, 특수 하드웨어(다양한 AI 칩) 활용이 확대되며, 대형 데이터센터 의존도를 일부 감소시키려는 움직임이 있습니다.
#
# 6) 오픈소스 생태계의 부상과 시장 다변화
# - 오픈소스 LLM의 활성화로 접근성과 비교 연구가 진전되고 있지만, 안전성/라이선스 이슈에 대한 논의도 함께 진행 중입니다.
# - 기업과 연구기관이 협업하거나 독자적인 생태계를 구축하는 사례가 늘고 있습니다.
#
# 7) AI를 통한 과학-산업 혁신의 가속
# - 제약/바이오, 재료과학, 에너지, 기후 연구 등에서 AI가 실험 설계, 데이터 해석, 시뮬레이션 가속화에 기여합니다.
# - 자동화된 연구 파이프라인(edge-to-research) 구축이 늘고 있습니다.
#
# 잠깐 짚고 넘어가면 유의할 점
# - 데이터 편향, 허위 정보 생성, 악용 가능성 등 위험 관리가 여전히 도전 과제로 남아 있습니다.
# - 기술 도입으로 인한 노동 변화, 규제 준수 비용 증가 등 비즈니스/정책 리스크를 함께 관리해야 합니다.
# - 에너지 소비/탄소 발자국 관리도 지속적으로 중요한 이슈입니다.
#
# 연구나 실무 관점에서 뾰족한 포커스가 필요하다면, 아래 중 하나를 골라 깊이 팔로우해 보시면 좋습니다.
# - 에이전트 기반 시스템의 안전성 및 도구 통합 방법
# - 데이터 중심 AI: 데이터 품질 평가, 합성 데이터의 신뢰성 개선
# - 멀티모달 모델의 실제 응용 사례와 평가 프레임워크
# - 파라미터 효율화와 하드웨어 최적화(온디바이스/엣지 AI)
# - 규제 대응 체계: 모델 카드/데이터 카드, 책임성과 투명성 도구의 표준화
#
# 특정 분야(예: 헬스케어, 금융, 제조)나 목적(연구, 실무 적용, 정책)으로 더 구체적으로 원하시면 맞춤으로 정리해 드릴게요. 어떤 방향으로 더 자세히 다뤄볼까요?
